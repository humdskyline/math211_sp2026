# %% [markdown]
# ### <a href="http://www.data8.org/sp20/python-reference.html"> Python Reference Link <a>
#
# Run the cell below so that we can set our modules up

# %%
import numpy as np
from datascience import *
import math

# %%
link = "https://raw.githubusercontent.com/humdskyline/data/main/first_class_survey_s2025.csv"
first_survey = Table.read_table(link)
first_survey.show(5)

# %% [markdown]
# ### 1. Write the Python code to find:
# <i>What is the average height of students in the class?</i>

# %% [markdown]
# ### 2. Write the Python code to find:
# <i>What is the average height of people that live in Daly City?</i>
#
# Include some comments to document your thought process

# %% [markdown]
# ### 3. Write the Python code to find:
# <i>What proportion of students in our class that live in Daly City?</i>
#
# Include some comments to document your thought process

# %% [markdown]
# #### 4.  Now try finding the major of the person in the fifth row
#
# Include some comments to document your thought process
