# %% [markdown]
# ### <a href="http://www.data8.org/sp20/python-reference.html"> Python Reference Link <a>
#
# Run the cell below so that we can set our modules up

# %%
import numpy as np
from datascience import *
import math

# %% [markdown]
# ## Here is a table that we want to create.  It's called print_jobs
#
# ![image.png](attachment:521f8ed9-7e9b-4371-99eb-58dc769a46c0.png)

# %% [markdown]
# ### First, let's create an Array for each column of data

# %%
# Here are some of the columns as arrays

#job_id
job_id = make_array(1, 2, 3, 4, 5, 6, 7, 8)

#pages -- you do this one
pages = ...

#color
bw = "Black & White"
col = "Color"
color = make_array(bw, col, bw, col, bw, col, bw, col)

#device -- you do this one
device = 

#Let's check our arrays to make sure they are correct
print(job_id)
print(pages)
print(color)
print(device)

# %% [markdown]
# ### Now that we have the columns, we can create the table print_jobs

# %%
#Now we need to create the table print_jobs.  Finish the code
print_jobs = ...
print_jobs

# %% [markdown]
# ### 1. Write the Python code to find:
# <i>How many pages were printed today?</i>

# %% [markdown]
# ### 2. Write the Python code to find:
# <i>How many pages were printed in color?</i>
#
# Include some comments to document your thought process

# %% [markdown]
# ### 3. Write the Python code to find:
# <i>What devices were used to print more color copies?</i>
#
# Include some comments to document your thought process

# %% [markdown]
# #### 4. Write the Python code to find:
# <i>If we have two printers, but only one print log, what is the estimated number of pages that have been printed today?</i>
#
# Include some comments to document your thought process
