# %% [markdown]
# # Welcome to JupyterHub Notebooks!

# %% [markdown]
# ### Checklist for each time you open a notebook file:
# 1. Toggle Line Numbers 'On'
# 2. Run all previous cells (if you are continuing your work from before)

# %% [markdown]
# ### Click the following Hyperlink for the: [Python Reference Page](https://www.data8.org/sp22/python-reference.html)

# %% [markdown]
# ### Run the following cell to load the Python modules we will need in this notebook

# %%
import numpy as np
from datascience import *
import math

# %% [markdown]
# #### Here is a text cell
#
# Text cells (like this one) can be edited by double-clicking on them. They're written in a simple format called [Markdown](http://daringfireball.net/projects/markdown/syntax) to add formatting and section headings.  You don't need to learn Markdown, but you might want to.

# %%
# Here is a code cell, 
print('Hello World')

# %% [markdown]
# ### Adding Cells
# In general, do NOT delete cells -- especially the Lab and Homework notebooks

# %% [markdown]
# # Numbers

# %% [markdown]
# ### Load the survey dataset

# %%
10/3

# %%
3

# %%
3.0

# %%
1.329487569238476592348765293456293478650234875029438

# %%
#What do you think the ** means?
123.5**123

# %% [markdown]
# # Strings

# %%
#A string is text inside quotes (either single or double)
"Here is a string"

# %% [markdown]
# Try writing the same string using double quotes

# %%
greeting = "Good afternoon"

# %%
greeting

# %%
greeting + " class"

# %%
x = "ha"
"mua" + x*10

# %% [markdown]
# ## To begin exploring our class survey, we first need to load the dataset into a Table
#
# ### Run the following cell

# %%
link = "https://raw.githubusercontent.com/humdskyline/data/main/class_survey_s2026_cleaned.csv"
first_survey = Table.read_table(link)

# %% [markdown]
# ### The first thing we should always to is to see what the first five rows of the Table look like

# %%
first_survey.show(5)

# %% [markdown]
# ### We can see what all of the column names are

# %%
first_survey.labels

# %% [markdown]
# # Submitting Notebooks

# %% [markdown]
# Export your notebook as HTML, and then upload that HTML file to Canvas.
