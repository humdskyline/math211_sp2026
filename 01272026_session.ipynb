# %% [markdown]
# ### <a href="http://www.data8.org/sp20/python-reference.html"> Python Reference Link <a>
#
# Run the cell below so that we can set our modules up

# %%
import numpy as np
from datascience import *

# %%
link = "https://raw.githubusercontent.com/humdskyline/data/main/class_survey_s2026_cleaned.csv"
first_survey = Table.read_table(link)
first_survey.show(5)

# %% [markdown]
# ### 1. Find the students that live in San Bruno.
#
# Include some comments to document your thought process

# %% [markdown]
# ### 2. What are everyone's heights and majors?

# %% [markdown]
# ### 3. Who are the students who are between 63 and 68 inches tall?

# %% [markdown]
# ### 4. What are the most meals people in the class eat daily?.

# %% [markdown]
# ### 5. What are the majors and favorite colors of people who are at least 65 inches tall?
