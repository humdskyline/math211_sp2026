# %% [markdown]
# ###Importing Python libraries that we will be using.  Just run this cell.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Loading the dataset.  Just run this cell.

# %%
link = "https://raw.githubusercontent.com/humdskyline/data/main/CollegeScores2year.csv"
scores_df = pd.read_csv(link)

# %% [markdown]
# ### Let's start exploring the data by looking at the first few rows.

# %%
scores_df.head()

# %% [markdown]
# ### And look at the summary statistics.  Notice that some of these statistics are useful, but others, we should just ignore.  Python will compute it all, whether or not we should actually do or use it

# %%
scores_df.describe()

# %% [markdown]
# ### What is something that you notice about the data?  What is something that you want to look into further?

# %% [markdown]
# ### Try writing code to select two or three different columns

# %% [markdown]
# ### What are the names of the regions?

# %%
regions = scores_df["Region"].unique()
regions

# %% [markdown]
# ### What are the unique Control types of the schools?

# %%
control = ...
control

# %% [markdown]
# ### Create a DataFrame with just the Private colleges

# %%
private_df = ...
private_df.head()

# %% [markdown]
# ### Create a DataFrame with just the Public colleges

# %%
public_df = ...
public_df.head()

# %% [markdown]
# ### Create a DataFrame with just the For Profit colleges

# %%
for_profit_df = ...
for_profit_df.head()

# %% [markdown]
# ### Get the in-state tuition for each type/control of school

# %%
public_tuition = ...
private_tuition = ...
for_profit_tuition = ...

# %% [markdown]
# ### Summary statistics for public in-state tuition

# %% [markdown]
# ### Summary statistics for private in-state tuition

# %% [markdown]
# ### Summary statistics for for profit in-state tuition

# %% [markdown]
# ### What do you notice about the in-state tuitions for private, public, and for profit colleges?

# %% [markdown]
# ### Here's another way to find the same information using the original table and the groupby function

# %%
scores_by_control_gb = scores_df.groupby("Control")
scores_by_control_gb["TuitionIn"].describe()

# %% [markdown]
# ### What can we find out about Skyline College?  (This is one way to look closer at one row of the DataFrame)

# %%
skyline = scores_df[scores_df['Name'] == "Skyline College"]
skyline

# %% [markdown]
# ### What question do you have of this dataset?

# %% [markdown]
# ### Write the code that will help you answer your question
